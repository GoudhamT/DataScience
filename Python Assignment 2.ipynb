# %% [markdown]
# ## 1. Create the below pattern using nested for loop in Python.
# ## *
# ## **
# ## ***
# ## ****
# ## *****
# ## ****
# ## ***
# ## **
# ## *

# %%
i = 0
for star in range (1,6):
    print('*' * star)
    i += 1
    if i == 5:
        for revstar in range(5,0,-1):
            print((revstar-1)* '*')
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ## 2. Write a Python program to reverse a word after accepting the input from the user.

# %%
word = input("Please enter any word you like \n")
print(word[::-1].lower())
# Out:
# Please enter any word you like
# ineuron
# norueni
